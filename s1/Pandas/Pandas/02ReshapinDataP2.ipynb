# %%
import pandas as pd

# %%
df = pd.read_excel("./Data/Cars_data.xlsx")

# %%
df = df.sort_values(['کیلومتر کارکرد' ,'قیمت بازار' ], ascending = [False , True])

# %%
df.sort_index()
# Out:
#              تاریخ  کیلومتر کارکرد          شماره شاسی      سازنده   Model  \
# 0       1400-1-تیر         24393.0  NA0000000000000200       سایپا   پراید
# 1       1400-2-تیر         18177.0  NA0000000000000201       سایپا   پراید
# 2       1400-3-تیر         20600.0  NA0000000000000202       سایپا   پراید
# 3       1400-4-تیر         26210.0  NA0000000000000203       سایپا   پراید
# 4       1400-5-تیر         24213.0  NA0000000000000204       سایپا   پراید
# ..             ...             ...                 ...         ...     ...
# 192   1400-7-مرداد         20468.0  NA0000000000000392  ایرانخودرو  پژو206
# 193   1400-8-مرداد         20747.0  NA0000000000000393  ایرانخودرو  پژو206
# 194   1400-9-مرداد         20397.0  NA0000000000000394  ایرانخودرو  پژو206
# 195  1400-10-مرداد         24358.0  NA0000000000000395  ایرانخودرو  پژو206
# 196  1400-11-مرداد         27363.0  NA0000000000000396  ایرانخودرو  پژو206
#
#           Type  قیمت بازار  قیمت کارخانه     توضیحات
# ...

# %%
df.reset_index()
# Out:
#      index           تاریخ  کیلومتر کارکرد          شماره شاسی      سازنده  \
# 0       75  1400-14-شهریور         37886.0  NA0000000000000275       سایپا
# 1      140   1400-17-مرداد         37360.0  NA0000000000000340       سایپا
# 2        9     1400-10-تیر         36638.0  NA0000000000000209       سایپا
# 3       74  1400-13-شهریور         33959.0  NA0000000000000274       سایپا
# 4      139   1400-16-مرداد         33585.0  NA0000000000000339       سایپا
# ..     ...             ...             ...                 ...         ...
# 192     76  1400-15-شهریور          8268.0  NA0000000000000276       سایپا
# 193    182  1400-28-شهریور          4863.0  NA0000000000000382  ایرانخودرو
# 194     51   1400-21-مرداد          4168.0  NA0000000000000251  ایرانخودرو
# 195    117     1400-25-تیر          3385.0  NA0000000000000317  ایرانخودرو
# 196    165  1400-11-شهریور             NaN  NA0000000000000365         NaN
#
#       Model       Type  قیمت بازار  قیمت کارخانه     توضیحات
# ...

# %%
df
# Out:
#               تاریخ  کیلومتر کارکرد          شماره شاسی      سازنده   Model  \
# 75   1400-14-شهریور         37886.0  NA0000000000000275       سایپا   پراید
# 140   1400-17-مرداد         37360.0  NA0000000000000340       سایپا   پراید
# 9       1400-10-تیر         36638.0  NA0000000000000209       سایپا   پراید
# 74   1400-13-شهریور         33959.0  NA0000000000000274       سایپا   پراید
# 139   1400-16-مرداد         33585.0  NA0000000000000339       سایپا   پراید
# ..              ...             ...                 ...         ...     ...
# 76   1400-15-شهریور          8268.0  NA0000000000000276       سایپا   پراید
# 182  1400-28-شهریور          4863.0  NA0000000000000382  ایرانخودرو  پژو206
# 51    1400-21-مرداد          4168.0  NA0000000000000251  ایرانخودرو  پژو206
# 117     1400-25-تیر          3385.0  NA0000000000000317  ایرانخودرو  پژو206
# 165  1400-11-شهریور             NaN  NA0000000000000365         NaN  پژو206
#
#           Type  قیمت بازار  قیمت کارخانه     توضیحات
# ...

# %%
list (df.columns)
# Out:
# ['تاریخ',
#  'کیلومتر کارکرد',
#  'شماره شاسی',
#  'سازنده',
#  'Model',
#  'Type',
#  'قیمت بازار',
#  'قیمت کارخانه',
#  'توضیحات']

# %%
fa_cols = ['تاریخ',
 'کیلومتر کارکرد',
 'شماره شاسی',
 'سازنده',
 'Model',
 'Type',
 'قیمت بازار',
 'قیمت کارخانه',
 'توضیحات']
en_col = ['Date',
 'Milage',
 'VIN',
 'Made',
 'Model',
 'Type',
 'Price',
 'Order',
 'Explain']

# %%
cols_dict = dict(zip (fa_cols , en_col))

# %%
cols_dict
# Out:
# {'تاریخ': 'Date',
#  'کیلومتر کارکرد': 'Milage',
#  'شماره شاسی': 'VIN',
#  'سازنده': 'Made',
#  'Model': 'Model',
#  'Type': 'Type',
#  'قیمت بازار': 'Price',
#  'قیمت کارخانه': 'Order',
#  'توضیحات': 'Explain'}

# %%
df.rename(columns = cols_dict, inplace = True)

# %%
df
# Out:
#               Date   Milage                 VIN        Made   Model  \
# 0       1400-1-تیر  24393.0  NA0000000000000200       سایپا   پراید
# 1       1400-2-تیر  18177.0  NA0000000000000201       سایپا   پراید
# 2       1400-3-تیر  20600.0  NA0000000000000202       سایپا   پراید
# 3       1400-4-تیر  26210.0  NA0000000000000203       سایپا   پراید
# 4       1400-5-تیر  24213.0  NA0000000000000204       سایپا   پراید
# ..             ...      ...                 ...         ...     ...
# 192   1400-7-مرداد  20468.0  NA0000000000000392  ایرانخودرو  پژو206
# 193   1400-8-مرداد  20747.0  NA0000000000000393  ایرانخودرو  پژو206
# 194   1400-9-مرداد  20397.0  NA0000000000000394  ایرانخودرو  پژو206
# 195  1400-10-مرداد  24358.0  NA0000000000000395  ایرانخودرو  پژو206
# 196  1400-11-مرداد  27363.0  NA0000000000000396  ایرانخودرو  پژو206
#
#           Type       Price       Order     Explain
# 0    Hatchback  17049382.0  17000000.0      بی رنگ
# ...

# %%
df.drop(columns= ["Model","Type"] , inplace = True)

# %%
df
# Out:
#               تاریخ  کیلومتر کارکرد          شماره شاسی      سازنده  \
# 75   1400-14-شهریور         37886.0  NA0000000000000275       سایپا
# 140   1400-17-مرداد         37360.0  NA0000000000000340       سایپا
# 9       1400-10-تیر         36638.0  NA0000000000000209       سایپا
# 74   1400-13-شهریور         33959.0  NA0000000000000274       سایپا
# 139   1400-16-مرداد         33585.0  NA0000000000000339       سایپا
# ..              ...             ...                 ...         ...
# 76   1400-15-شهریور          8268.0  NA0000000000000276       سایپا
# 182  1400-28-شهریور          4863.0  NA0000000000000382  ایرانخودرو
# 51    1400-21-مرداد          4168.0  NA0000000000000251  ایرانخودرو
# 117     1400-25-تیر          3385.0  NA0000000000000317  ایرانخودرو
# 165  1400-11-شهریور             NaN  NA0000000000000365         NaN
#
#      قیمت بازار  قیمت کارخانه     توضیحات
# 75   21931446.0    17000000.0      فابریک
# 140  22836393.0    17000000.0      فابریک
# ...
